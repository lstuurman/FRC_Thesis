# %%
import pandas as pd
import numpy as np
import re
import glob
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale = 1.4)

# %%
data = pd.read_csv('../results/CPM_nofrc1.csv',index_col=0)

# %%
data = data.fillna(0)

# %%
data
# Out:
#         Motility   Persistance  AutoSlope     P-val  Lambda  Max_act
# 0       0.000000      0.000000   0.000000  0.000000     697      392
# 1    3156.979950   7268.215993  -0.000069  0.678288    7168      390
# 2       0.070493     10.733498   0.000000  0.000000     697     1582
# 3     931.877570  17897.841410   0.000227  0.168738    3684    12561
# 4    3509.015832  44076.644304  -0.000064  0.699189   10000    49992
# ..           ...           ...        ...       ...     ...      ...
# 311  2986.200984  38457.825341  -0.000042  0.812004    7168    25061
# 312     0.000000      0.000000   0.000000  0.000000     499      190
# 313     0.000000      0.000000   0.000000  0.000000    2640      390
# 314     0.017096      3.810399   0.000000  0.000000     972      791
# 315  2817.106260  30491.508547   0.000073  0.697857    7168     3150
#
# [316 rows x 6 columns]
