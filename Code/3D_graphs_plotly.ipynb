# %%
import plotly as py
import plotly.graph_objs as go
import networkx as nx
import numpy as np
from mayavi import mlab
import plotly.express as px

# %%
g = nx.random_geometric_graph(200,.3, dim=3, p=2, seed=None)
# extract postition directly from graph : 
pos = []
for n in g.nodes(data = True):
    #print(n)
    pos.append(n[1]['pos'])
    
xyz = np.array(pos)
x,y,z = xyz.T
degrees = [d[-1]/100 for d in g.degree()]

# %%
x_edges = []
y_edges = []
z_edges = []

for edge in g.edges():
#     print(edge)
#     print(g.nodes[edge[0]]['pos'])
    x0, y0, z0 = g.nodes[edge[0]]['pos']
    x1, y1, z1 = g.nodes[edge[1]]['pos']
#     x2, y2, z2 = g.nodes[edge[2]]['pos']
    x_edges.append(x0)
    x_edges.append(x1)
#     x_edges.append(x2)
    x_edges.append(None)
    y_edges.append(y0)
    y_edges.append(y1)
#     y_edges.append(y2)
    y_edges.append(None)
    z_edges.append(z0)
    z_edges.append(z1)
#     z_edges.append(z2)
    z_edges.append(None)

# %%
trace1=go.Scatter3d(x=x_edges,
               y=y_edges,
               z=z_edges,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=1.5)
               )

# trace1 = go.Scatter3d(
#     x=x, y=y, z=z,
#     marker=dict(
#         size=6,
#         color=z,
#         colorscale='Viridis',
#     ),
#     line=dict(
#         color='#1f77b4',
#         width=1
#     )
# )

trace2=go.Scatter3d(x=x,
               y=y,
               z=z,
               mode='markers',
               marker=dict(symbol='circle',
                             size=7,
                             color=degrees,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             )
               )

# trace2 = go.line_3d(x,y,z)

axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="3D Representation of randomg geometric graph",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ))#,
#      margin=dict(
#         t=100
#     ),
#     hovermode='closest',
#     annotations=[
#            dict(
#            showarrow=False,
#             xref='paper',
#             yref='paper',
#             x=0,
#             y=0.1,
#             xanchor='left',
#             yanchor='bottom',
#             font=dict(
#             size=14
#             )
#             )
#         ],    )

# %%
data=[trace1,trace2]
fig=go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="2a076bda-60c5-4597-a7aa-450afb6741f1" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a076bda-60c5-4597-a7aa-450afb6741f1")) {
#                     Plotly.newPlot(
#                         '2a076bda-60c5-4597-a7aa-450afb6741f1',
#                         [{"line": {"color": "rgb(125,125,125)", "width": 1.5}, "mode": "lines", "type": "scatter3d", "x": [0.31406677010298945, 0.3463764353924923, null, 0.31406677010298945, 0.425594828409371, null, 0.31406677010298945, 0.38478690339771904, null, 0.31406677010298945, 0.40103861533162144, null, 0.31406677010298945, 0.41293165686864364, null, 0.31406677010298945, 0.5467124411753329, null, 0.31406677010298945, 0.25595752963675755, null, 0.9463584293952606, 0.9628347129271617, null, 0.9463584293952606, 0.985915534703975, null, 0.9463584293952606, 0.9832151991316417, null, 0.9463584293952606, 0.7719402688926954, null, 0.9463584293952606, 0.8295307252010438, null, 0.9463584293952606, 0.7380651799154517, null, 0.9463584293952606, 0.7999886778131521, null, 0.9463584293952606, 0.7156397901363319, null, 0.9463584293952606, 0.8938521365633364, null, 0.9463584293952606, 0.8049657258197376, null, 0.9463584293952606, 0.9994351872351983, null, 0.9463584293952606, 0.7374969815798015, null, 0.5201169913867069, 0.36536213736481304, null, 0.5201169913867