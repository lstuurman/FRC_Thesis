# %%
import numpy as np 
import glob
from CPM_helpers1 import *
from MSD1cell import *
import pandas as pd
import re 
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
sns.set_style('darkgrid')

# %%
general_df = pd.read_csv('../results/fullCPM_frc1.csv',index_col = 0)

# %%
general_df.head()
# Out:
#    Cellid    Motility  Persistance  AutoSlope         P-val  Lambda  Max_act  \
# 0       0    0.000000     0.000000        NaN           NaN    5000      155
# 1     130   99.427866   187.226440  -0.000541  2.915255e-02   10000      261
# 2     212  124.203067   230.998282  -0.001437  1.941236e-09    5000      894
# 3      69  104.250155   452.592393  -0.001830  1.495328e-10    5000      366
# 4      60   29.627928    46.185997  -0.001806  6.298796e-16   10000      261
#
#       Speed
# 0  0.000000
# 1  0.950946
# 2  0.924359
# 3  0.704571
# 4  1.065870

# %%
print(max(general_df.Speed.unique()))
# Out:
# 5.472778443402435

# %%
sns.set_palette("deep")
plt.figure(figsize = (10,10))
sns.lineplot(x = 'Lambda',y = 'Speed',hue = 'Max_act',legend = 'full',data = general_df)
plt.show()
